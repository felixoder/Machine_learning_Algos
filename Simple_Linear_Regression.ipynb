# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
# Evaluation
from sklearn.metrics import mean_squared_error, r2_score

# %%
# upload dataset
file_path = "house_data.csv"
data = pd.read_csv(file_path)
print(data.head())
# Out:
#    House Size (sq ft)  Price (USD)
# 0                1736       278731
# 1                 504       180012
# 2                1871       158212
# 3                1855       378345
# 4                2158       191645

# %%
# Spliting the data
X = data['House Size (sq ft)'].values.reshape(-1, 1)
Y = data['Price (USD)'].values
# Split the data into traininga and testing sets (80% train, 20% test)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

# %%
# Training the model
model = LinearRegression()
# Train the model
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# Making predictions
Y_pred = model.predict(X_test)
# print actual vs predicted values
print("Actual prices:", Y_test)
print("Predicted prices:", Y_pred)
# Out:
# Actual prices: [443961 432421 177530 169683 310606 394423 226691 317401 313093 337682
#  495032 403623 146460 178754 482137 420696 248993 308121 133584 467073
#  428118 445968 475296 198141 225925 493037 226806 271066 386033 266824
#  421269 165319 268191 480661 195468 186166 152626 252176 326577 230720
#  503115 300107 501665 352668 282638 281855 193778 285325 468416 448157
#  345101 154190 369843 316560 324863 426324 216350 452711 296598 220507
#  294580 402766 241958 426297 486220 508812 402234 230808 147431 435091
#  469344 439001 151800 369947 303846 354122 234690 137779 465610 288258
#  328438 508397 490807 327696 450583 492156 432281 397995 493377 395282
#  275381 231577 129982 294143 403182 484516 141600 501606 300662 393260
#  281989 334275 140992 369687 161243 404308 224465 348714 494624 187071
#  204955 303374 145126 228473 286619 416344 237046 252711 447673 373700
#  278865 437328 378924 412738 302899 374077 218221 203494 332304 282833
# ...

# %%
# Plotting the regression line
plt.scatter(X_train, Y_train, color = "blue", label = "Training Data")
plt.plot(X_train, model.predict(X_train), color = "red", label = "Regression Line")
plt.xlabel("House Size (sq ft)")
plt.ylabel("Price (USD)")
plt.title("Linear Regression - House Size vs Price")
plt.legend()
plt.show()

# %%
# Evaluation
# Calculate the Mean Squared Error (MSE)
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

print(f"Mean Squared Error:{mse}")
print(f"R^2 score:{r2}")
# Out:
# Mean Squared Error:12483035783.915565
# R^2 score:-0.0025704162251380946

# %%
# User Input for prediction
flat_size = float(input("\nEnter the size of the flat (in sq ft)"))
# Make prediction for the user-input size
predicted_price = model.predict([[flat_size]])
# Display the predicted price
print(f"The predicted price for a flat of size {flat_size} sq ft is: ${predicted_price[0]:,.2f}")
# Out:
# Enter the size of the flat (in sq ft)700
# The predicted price for a flat of size 700.0 sq ft is: $315,489.15
